# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjanareddyMalthumada/SanjanaICP_3/blob/main/ICP_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the Breast Cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=87)

# Neural network model with additional dense layers
model = Sequential()
model.add(Dense(20, input_dim=X_train.shape[1], activation='relu'))  # Adjusted input_dim for Breast Cancer dataset
model.add(Dense(64, activation='relu'))  # Additional dense layer
model.add(Dense(64, activation='relu'))  # Additional dense layer
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, Y_train, epochs=100, batch_size=10, verbose=1)

# Model summary
print(model.summary())

# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print(f'Test Accuracy: {accuracy*100:.2f}%')
# Out:
# Epoch 1/100
# 43/43 [==============================] - 2s 3ms/step - loss: 0.4440 - accuracy: 0.8592
# Epoch 2/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1383 - accuracy: 0.9531
# Epoch 3/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9789
# Epoch 4/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 0.9836
# Epoch 5/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0469 - accuracy: 0.9836
# Epoch 6/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0404 - accuracy: 0.9883
# Epoch 7/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 0.9906
# Epoch 8/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 0.9930
# Epoch 9/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9953
# Epoch 10/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.9930
# Epoch 11/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 0.9930
# Epoch 12/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9930
# Epoch 13/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9953
# Epoch 14/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9977
# Epoch 15/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 0.9977
# Epoch 16/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9977
# Epoch 17/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9977
# Epoch 18/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 19/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9977
# Epoch 20/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 21/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 22/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 23/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 24/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 25/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 26/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 27/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 28/100
# 43/43 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 29/100
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 30/100
# 43/43 [==============================] - 0s 4ms/step - loss: 8.6573e-04 - accuracy: 1.0000
# Epoch 31/100
# 43/43 [==============================] - 0s 5ms/step - loss: 8.2205e-04 - accuracy: 1.0000
# Epoch 32/100
# 43/43 [==============================] - 0s 5ms/step - loss: 8.5424e-04 - accuracy: 1.0000
# Epoch 33/100
# 43/43 [==============================] - 0s 6ms/step - loss: 5.9883e-04 - accuracy: 1.0000
# Epoch 34/100
# 43/43 [==============================] - 0s 6ms/step - loss: 5.9542e-04 - accuracy: 1.0000
# Epoch 35/100
# 43/43 [==============================] - 0s 5ms/step - loss: 4.9256e-04 - accuracy: 1.0000
# Epoch 36/100
# 43/43 [==============================] - 0s 4ms/step - loss: 5.4864e-04 - accuracy: 1.0000
# Epoch 37/100
# 43/43 [==============================] - 0s 3ms/step - loss: 5.1483e-04 - accuracy: 1.0000
# Epoch 38/100
# 43/43 [==============================] - 0s 4ms/step - loss: 4.3310e-04 - accuracy: 1.0000
# Epoch 39/100
# 43/43 [==============================] - 0s 4ms/step - loss: 4.4391e-04 - accuracy: 1.0000
# Epoch 40/100
# 43/43 [==============================] - 0s 3ms/step - loss: 3.4637e-04 - accuracy: 1.0000
# Epoch 41/100
# 43/43 [==============================] - 0s 3ms/step - loss: 3.1189e-04 - accuracy: 1.0000
# Epoch 42/100
# 43/43 [==============================] - 0s 3ms/step - loss: 2.8533e-04 - accuracy: 1.0000
# Epoch 43/100
# 43/43 [==============================] - 0s 3ms/step - loss: 2.7687e-04 - accuracy: 1.0000
# Epoch 44/100
# 43/43 [==============================] - 0s 4ms/step - loss: 2.3964e-04 - accuracy: 1.0000
# Epoch 45/100
# 43/43 [==============================] - 0s 8ms/step - loss: 2.1782e-04 - accuracy: 1.0000
# Epoch 46/100
# 43/43 [==============================] - 0s 7ms/step - loss: 2.1995e-04 - accuracy: 1.0000
# Epoch 47/100
# 43/43 [==============================] - 0s 10ms/step - loss: 1.9784e-04 - accuracy: 1.0000
# Epoch 48/100
# 43/43 [==============================] - 0s 9ms/step - loss: 2.1232e-04 - accuracy: 1.0000
100
# 43/43 [==============================] - 0s 3ms/step - loss: 2.9888e-05 - accuracy: 1.0000
# Epoch 83/100
# 43/43 [==============================] - 0s 2ms/step - loss: 2.8771e-05 - accuracy: 1.0000
# Epoch 84/100
# 43/43 [==============================] - 0s 3ms/step - loss: 2.8419e-05 - accuracy: 1.0000
# Epoch 85/100
# 43/43 [==============================] - 0s 6ms/step - loss: 2.6970e-05 - accuracy: 1.0000
# Epoch 86/100
# 43/43 [==============================] - 0s 6ms/step - loss: 2.6492e-05 - accuracy: 1.0000
# Epoch 87/100
# 43/43 [==============================] - 0s 6ms/step - loss: 2.5580e-05 - accuracy: 1.0000
# Epoch 88/100
# 43/43 [==============================] - 0s 4ms/step - loss: 2.4430e-05 - accuracy: 1.0000
# Epoch 89/100
# 43/43 [==============================] - 0s 6ms/step - loss: 2.2157e-05 - accuracy: 1.0000
# Epoch 90/100
# 43/43 [==============================] - 0s 5ms/step - loss: 2.1966e-05 - accuracy: 1.0000
# Epoch 91/100
# 43/43 [==============================] - 0s 5ms/step - loss: 2.1819e-05 - accuracy: 1.0000
# Epoch 92/100
# 43/43 [==============================] - 0s 5ms/step - loss: 2.0177e-05 - accuracy: 1.0000
# Epoch 93/100
# 43/43 [==============================] - 0s 5ms/step - loss: 1.9803e-05 - accuracy: 1.0000
# Epoch 94/100
# 43/43 [==============================] - 0s 5ms/step - loss: 1.8314e-05 - accuracy: 1.0000
# Epoch 95/100
# 43/43 [==============================] - 0s 7ms/step - loss: 1.7512e-05 - accuracy: 1.0000
# Epoch 96/100
# 43/43 [==============================] - 0s 5ms/step - loss: 1.6791e-05 - accuracy: 1.0000
# Epoch 97/100
# 43/43 [==============================] - 0s 6ms/step - loss: 1.5977e-05 - accuracy: 1.0000
# Epoch 98/100
# 43/43 [==============================] - 0s 5ms/step - loss: 1.6006e-05 - accuracy: 1.0000
# Epoch 99/100
# 43/43 [==============================] - 0s 6ms/step - loss: 1.5081e-05 - accuracy: 1.0000
# Epoch 100/100
# 43/43 [==============================] - 0s 6ms/step - loss: 1.4326e-05 - accuracy: 1.0000
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 20)                620
#
#  dense_19 (Dense)            (None, 64)                1344
#
#  dense_20 (Dense)            (None, 64)                4160
#
#  dense_21 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 6189 (24.18 KB)
# Trainable params: 6189 (24.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Test Accuracy: 96.50%

# %%
from keras.datasets import mnist
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocess the data
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData).astype('float32') / 255
test_data = test_images.reshape(test_images.shape[0], dimData).astype('float32') / 255
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# Creating the network
model = Sequential([
    Dense(512, activation='relu', input_shape=(dimData,)),
    Dense(512, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                    validation_data=(test_data, test_labels_one_hot))

# Plotting the accuracy and loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()
plt.show()

# Predicting a single image
def predict_single_image(image_data):
    image_data = image_data.reshape(1, dimData).astype('float32') / 255
    prediction = model.predict(image_data)
    predicted_class = np.argmax(prediction)
    return predicted_class

# Choose an image from the test set
image_index = 0  # Change this to see different predictions
predicted_class = predict_single_image(test_images[image_index])
print(f'Predicted class for image at index {image_index}: {predicted_class}')
plt.imshow(test_images[image_index], cmap='gray')
plt.title(f'Image at index {image_index} - Predicted as: {predicted_class}')
plt.show()

# Modify the model to use different activation functions and fewer layers for comparison
# You can adjust the following model architecture as needed
model_tanh = Sequential([
    Dense(512, activation='tanh', input_shape=(dimData,)),
    Dense(10, activation='softmax')
])

model_tanh.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model_tanh.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
               validation_data=(test_data, test_labels_one_hot))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 7s 27ms/step - loss: 0.2876 - accuracy: 0.9116 - val_loss: 0.1612 - val_accuracy: 0.9487
# Epoch 2/10
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0989 - accuracy: 0.9698 - val_loss: 0.0907 - val_accuracy: 0.9702
# Epoch 3/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0634 - accuracy: 0.9804 - val_loss: 0.1285 - val_accuracy: 0.9591
# Epoch 4/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0437 - accuracy: 0.9865 - val_loss: 0.0628 - val_accuracy: 0.9801
# Epoch 5/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0316 - accuracy: 0.9898 - val_loss: 0.0639 - val_accuracy: 0.9812
# Epoch 6/10
# 235/235 [==============================] - 9s 36ms/step - loss: 0.0230 - accuracy: 0.9926 - val_loss: 0.0721 - val_accuracy: 0.9794
# Epoch 7/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.0170 - accuracy: 0.9942 - val_loss: 0.0655 - val_accuracy: 0.9816
# Epoch 8/10
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.0648 - val_accuracy: 0.9835
# Epoch 9/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.0867 - val_accuracy: 0.9792
# Epoch 10/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0689 - val_accuracy: 0.9829
# 1/1 [==============================] - 0s 141ms/step
# Predicted class for image at index 0: 7
# Epoch 1/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3883 - accuracy: 0.8860 - val_loss: 0.2854 - val_accuracy: 0.9151
# Epoch 2/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.2321 - accuracy: 0.9320 - val_loss: 0.2042 - val_accuracy: 0.9393
# Epoch 3/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1692 - accuracy: 0.9510 - val_loss: 0.1529 - val_accuracy: 0.9554
# Epoch 4/10
# 235/235 [==============================] - 5s 23ms/step - loss: 0.1291 - accuracy: 0.9621 - val_loss: 0.1372 - val_accuracy: 0.9575
# Epoch 5/10
# 235/235 [==============================] - 5s 22ms/step - loss: 0.1036 - accuracy: 0.9698 - val_loss: 0.1197 - val_accuracy: 0.9635
# Epoch 6/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0841 - accuracy: 0.9765 - val_loss: 0.0988 - val_accuracy: 0.9698
# Epoch 7/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0704 - accuracy: 0.9794 - val_loss: 0.0857 - val_accuracy: 0.9732
# Epoch 8/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0594 - accuracy: 0.9830 - val_loss: 0.0870 - val_accuracy: 0.9740
# Epoch 9/10
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0503 - accuracy: 0.9852 - val_loss: 0.0784 - val_accuracy: 0.9758
# Epoch 10/10
# 235/235 [==============================] - 5s 23ms/step - loss: 0.0429 - accuracy: 0.9879 - val_loss: 0.0789 - val_accuracy: 0.9749
